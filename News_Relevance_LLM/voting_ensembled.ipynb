# %%
from transformers import pipeline
import pandas as pd
import newsRev_DeBERTa
import newsRev_BART
# Out:
# 2024-03-30 22:18:02.691704: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from langchain import PromptTemplate, LLMChain, OpenAI 
from langchain.memory import ConversationBufferMemory

import os

# %%
api_key = os.getenv("OPENAI_API_KEY")

# %%
df = pd.read_csv('News_Relevance_LLM/news relevancy - api_data.csv')

# %%
df.head()
# Out:
#                                                Title  \
# 0  Apple iOS 17.4: iMessage Gets Post-Quantum Enc...
# 1           These Companies Have a Plan to Kill Apps
# 2  Inside Finland’s state-of-the-art quantum comp...
# 3  New AI and 5G advancements will usher in the e...
# 4  Seeking nominations for the top creative agenc...
#
#                                                 Link  \
# 0  https://www.wired.com/story/apple-pq3-post-qua...
# 1  https://www.wired.com/story/these-companies-ha...
# 2  https://thenextweb.com/news/finland-quantum-co...
# 3  https://www.businessinsider.com/ai-edge-comput...
# 4  https://www.businessinsider.com/seeking-nomina...
#
#                                              Article  \
# 0  Apple is launching its first post-quantum prot...
# 1  In another example, Yue asks the phone to find...
# 2  In 1965, cryogenics pioneer Olli V. Lounasmaa ...
# 3  The AI boom is breathing life into edge comput...
# 4  Business Insider is seeking nominations for a ...
#
#                   newsCategory newsRelevancy groundTruth Unnamed: 6
# 0  Communications Technologies      Relevant    Relevant        NaN
# 1                           AI      Relevant    Relevant        NaN
# 2            Quantum Computing      Relevant    Relevant        NaN
# 3                           AI      Relevant    Relevant        NaN
# 4                           AI      Relevant    Relevant        NaN

# %%
def relevance_GPT(article_insert):
    print('RELEVANCE GPT FUNCTION WORKING')
    try:
        #Defining Function + ChatGPT
        #Langchain implementation
        template = """ You are a bot that will be given an article and to deem if it is relevant to technology. 
        Please answer with Relevant or Irrelevant 

        Technology also includes the following:
        
        AI includes Discriminative AI, Machine Learning, Generative AI

        Quantum Computing includes Quantum Internet, Quantum Communications, Quatum Computing

        Green Computing includes Green Serverless Computing, Green Edge Applications, Green Data Streaming

        Robotics

        Trust Technologies includes Privacy Enhancing Technologies, Regulation Technologies, Al Governance Technologies

        Anti-disinformation technologies includes Content Provenance Technologies, Anti-misinformation technologies, Detection of Generated Al content

        Communications Technologies includes 5G, Networks, Seamless

        In terms of the article information, classify them as Relevant or Irrelevant. 

        Make sure that there are no spacing before the first word.


        Human: {article}
        Assistant:"""

        prompt = PromptTemplate(
            input_variables=["article"], 
            template=template
        )

        chatgpt_chain = LLMChain(
            llm = OpenAI(openai_api_key=api_key,model="gpt-3.5-turbo-instruct", temperature=0), 
            prompt=prompt, 
            verbose=False,  # Set verbose to False to suppress output
            memory=ConversationBufferMemory(memory_key="history", input_key="article")
        )
        #Let ChatGPT to Categorise
        output = chatgpt_chain.predict(article=article_insert) 

        #To make sure that there are no spacing which ChatGPT outputs " Category_Name" -> "Category_Name"
        output = output.strip()

        return output

    except Exception as e:
        print(f"An error occurred: {e}")
        return "Irrelevant"  # Return 'Irrelevant'' category in case of error

# %%
def newsRelevancy(article_content):
    countRelevance = 0
    
    gpt_Relevance = relevance_GPT(article_content)
    if (gpt_Relevance == "Relevant"):
        countRelevance += 1

    #print("GPT:")
    #print(gpt_Relevance)

    #LLM 1
    bart_Relevance = newsRev_BART.bart_Function(article_content)
    if (bart_Relevance == "Relevant"):
        countRelevance += 2
    #print("BART:")
    #print(bart_Relevance)
    #LLM 2
    deberta_relevance = newsRev_DeBERTa.DeBERTa_Function(article_content)
    if (deberta_relevance == "Relevant"):
        countRelevance += 3
    #print("deBerta:")
    #print(deberta_relevance)
        
    #False to deem article not relevant
    if countRelevance >= 3:
        #print("Final: Relevant")
        return 'Relevant'
    else:
        #print("Final: Irrelevant")
        return 'Irrelevant'

# %%
print(newsRelevancy("Finance Business"))
# Out:
# RELEVANCE GPT FUNCTION WORKING
# /opt/homebrew/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(
# GPT:
# Irrelevant
# Finance
# BART:
# Irrelevant
# Business
# deBerta:
# Irrelevant
# Final: Irrelevant
# Irrelevant

# %%
df['Voting'] = df['Article'].apply(newsRelevancy)
# Out:
# RELEVANCE GPT FUNCTION WORKING
# /Users/jackho/Downloads/BT4103/Capstone Proj/BT4103/.venv/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# An error occurred: Error code: 400 - {'error': {'message': "This model's maximum context length is 4097 tokens, however you requested 5626 tokens (5370 in your prompt; 256 for the completion). Please reduce your prompt; or completion length.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# An error occurred: Error code: 400 - {'error': {'message': "This model's maximum context length is 4097 tokens, however you requested 5702 tokens (5446 in your prompt; 256 for the completion). Please reduce your prompt; or completion length.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING
# RELEVANCE GPT FUNCTION WORKING

# %%
df['Voting']
# Out:
# 0        Relevant
# 1        Relevant
# 2        Relevant
# 3        Relevant
# 4        Relevant
#           ...
# 145    Irrelevant
# 146    Irrelevant
# 147    Irrelevant
# 148    Irrelevant
# 149    Irrelevant
# Name: Voting, Length: 150, dtype: object

# %%
# Separate predictions and ground truth
predictions = df['Voting']  # Assuming predictions are in the first row
ground_truth = df['groundTruth']  # Assuming ground truth is in the second row

# %%
#print(predictions)

# Compare predictions and ground truth
correct_predictions = (predictions == ground_truth).sum()
total_predictions = len(predictions)

# Print results
print("Predictions:", predictions.values)
print("Ground Truth:", ground_truth.values)
print("Number of correct predictions:", correct_predictions)
print("Total predictions made:", total_predictions)
print("Accuracy:", correct_predictions / total_predictions)
# Out:
# Predictions: ['Relevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Relevant' 'Irrelevant' 'Relevant' 'Irrelevant' 'Irrelevant' 'Relevant'
#  'Relevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant'
#  'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Relevant'
#  'Irrelevant' 'Irrelevant' 'Relevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant'
#  'Relevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant'
#  'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant'
#  'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Relevant'
#  'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Irrelevant'
#  'Relevant' 'Irrelevant' 'Irrelevant' 'Relevant' 'Relevant' 'Relevant'
#  'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant'
#  'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant' 'Irrelevant'
#  'Relevant' 'Irrelevant' 'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Irrelevant' 'Irrelevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant'
#  'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant'
#  'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Irrelevant' 'Irrelevant'
#  'Irrelevant' 'Relevant' 'Irrelevant' 'Irrelevant' 'Relevant' 'Relevant'
#  'Relevant' 'Irrelevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant'
#  'Irrelevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Irrelevant' 'Irrelevant' 'Irrelevant' 'Irrelevant' 'Irrelevant'
#  'Irrelevant']
# Ground Truth: ['Relevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant' 'Irrelevant'
#  'Relevant' 'Irrelevant' 'Irrelevant' 'Irrelevant' 'Relevant' 'Relevant'
#  'Relevant' 'Irrelevant' 'Relevant' 'Irrelevant' 'Relevant' 'Irrelevant'
#  'Relevant' 'Relevant' 'Irrelevant' 'Irrelevant' 'Irrelevant' 'Relevant'
#  'Irrelevant' 'Irrelevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant'
#  'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant'
#  'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant'
#  'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant'
#  'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Relevant'
#  'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant'
#  'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant'
#  'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Relevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant'
#  'Irrelevant' 'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant'
#  'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Irrelevant'
#  'Irrelevant' 'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant'
#  'Relevant' 'Relevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant'
#  'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Irrelevant' 'Irrelevant'
#  'Irrelevant' 'Relevant' 'Irrelevant' 'Irrelevant' 'Irrelevant' 'Relevant'
#  'Irrelevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant' 'Relevant'
#  'Irrelevant' 'Relevant' 'Relevant' 'Relevant' 'Irrelevant' 'Relevant'
#  'Irrelevant' 'Irrelevant' 'Irrelevant' 'Irrelevant' 'Irrelevant'
#  'Irrelevant']
# Number of correct predictions: 122
# Total predictions made: 150
# Accuracy: 0.8133333333333334

# %%
#As it took pretty long to run the Voting. I will export out the column.
#column_to_export = df['Voting']

# Export the column to a CSV file
#column_to_export.to_csv('voting_column.csv', index=False)

# %%
import feedparser

# %%
rss_feed_url = "https://techxplore.com/rss-feed/machine-learning-ai-news/"
feed = feedparser.parse(rss_feed_url)

# %%
import scrapy
from newspaper import Article

# %%
rss_feed_url = "https://techxplore.com/rss-feed/machine-learning-ai-news/"
feed = feedparser.parse(rss_feed_url)

for entry in feed.entries:
    print(entry.published)
# Out:
# Sat, 30 Mar 2024 09:00:01 EDT
# Sat, 30 Mar 2024 06:23:09 EDT
# Sat, 30 Mar 2024 06:10:01 EDT
# Fri, 29 Mar 2024 13:58:02 EDT
# Fri, 29 Mar 2024 13:36:32 EDT
# Fri, 29 Mar 2024 13:36:26 EDT
# Fri, 29 Mar 2024 12:22:58 EDT
# Fri, 29 Mar 2024 09:32:00 EDT
# Thu, 28 Mar 2024 17:40:04 EDT
# Thu, 28 Mar 2024 16:49:00 EDT
# Thu, 28 Mar 2024 16:30:03 EDT
# Thu, 28 Mar 2024 15:08:02 EDT
# Thu, 28 Mar 2024 14:10:06 EDT
# Thu, 28 Mar 2024 14:06:02 EDT
# Thu, 28 Mar 2024 14:05:03 EDT
# Thu, 28 Mar 2024 13:33:05 EDT
# Thu, 28 Mar 2024 08:47:53 EDT
# Wed, 27 Mar 2024 16:50:54 EDT
# Wed, 27 Mar 2024 15:48:05 EDT
# Wed, 27 Mar 2024 12:30:02 EDT
# Wed, 27 Mar 2024 11:22:14 EDT
# Wed, 27 Mar 2024 04:51:01 EDT
# Tue, 26 Mar 2024 10:05:51 EDT
# Mon, 25 Mar 2024 17:05:57 EDT
# Mon, 25 Mar 2024 15:46:05 EDT
# Mon, 25 Mar 2024 13:00:01 EDT
# Mon, 25 Mar 2024 12:54:01 EDT
# Mon, 25 Mar 2024 09:48:48 EDT
# Mon, 25 Mar 2024 09:48:20 EDT
# Mon, 25 Mar 2024 09:34:06 EDT

# %%
rss_feed_url = "https://techxplore.com/rss-feed/machine-learning-ai-news/"
feed = feedparser.parse(rss_feed_url)

for entry in feed.entries:
    print(entry)
# Out:
# {'title': 'An optimization-based method to enhance autonomous parking', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'An optimization-based method to enhance autonomous parking'}, 'summary': 'Vehicles that can drive themselves have been a long sought after goal both of robotics research and the automotive industry. While various companies have been investing in these vehicles and testing them, they have so far only deployed them in a limited number of settings.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Vehicles that can drive themselves have been a long sought after goal both of robotics research and the automotive industry. While various companies have been investing in these vehicles and testing them, they have so far only deployed them in a limited number of settings.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-optimization-based-method-autonomous.html'}], 'link': 'https://techxplore.com/news/2024-03-optimization-based-method-autonomous.html', 'tags': [{'term': 'Automotive', 'scheme': None, 'label': None}], 'published': 'Sat, 30 Mar 2024 09:00:01 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=30, tm_hour=13, tm_min=0, tm_sec=1, tm_wday=5, tm_yday=90, tm_isdst=0), 'id': 'news630932731', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/an-optimization-based.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'OpenAI unveils voice-cloning tool', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'OpenAI unveils voice-cloning tool'}, 'summary': 'OpenAI on Friday revealed a voice-cloning tool it plans to keep tightly controlled until safeguards are in place to thwart audio fakes meant to dupe listeners.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'OpenAI on Friday revealed a voice-cloning tool it plans to keep tightly controlled until safeguards are in place to thwart audio fakes meant to dupe listeners.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-openai-unveils-voice-cloning-tool.html'}], 'link': 'https://techxplore.com/news/2024-03-openai-unveils-voice-cloning-tool.html', 'tags': [{'term': 'Internet', 'scheme': None, 'label': None}], 'published': 'Sat, 30 Mar 2024 06:23:09 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=30, tm_hour=10, tm_min=23, tm_sec=9, tm_wday=5, tm_yday=90, tm_isdst=0), 'id': 'news630998583', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/openai-says-ways-to-ve.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Generative AI is changing the legal profession. Future lawyers need to know how to use it', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Generative AI is changing the legal profession. Future lawyers need to know how to use it'}, 'summary': "Generative AI—technology such as ChatGPT that creates content when prompted—is affecting how solicitors, judges and barristers work. It's also likely to change the work they are being asked to do.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "Generative AI—technology such as ChatGPT that creates content when prompted—is affecting how solicitors, judges and barristers work. It's also likely to change the work they are being asked to do."}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-generative-ai-legal-future-lawyers.html'}], 'link': 'https://techxplore.com/news/2024-03-generative-ai-legal-future-lawyers.html', 'tags': [{'term': 'Business', 'scheme': None, 'label': None}], 'published': 'Sat, 30 Mar 2024 06:10:01 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=30, tm_hour=10, tm_min=10, tm_sec=1, tm_wday=5, tm_yday=90, tm_isdst=0), 'id': 'news630933022', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/computers-library.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Brain-inspired chaotic spiking backpropagation', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Brain-inspired chaotic spiking backpropagation'}, 'summary': 'Since it was discovered in the 1980s that learning in the rabbit brain utilizes chaos, this nonlinear and initially value-sensitive dynamical behavior has been increasingly recognized as integral to brain learning.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Since it was discovered in the 1980s that learning in the rabbit brain utilizes chaos, this nonlinear and initially value-sensitive dynamical behavior has been increasingly recognized as integral to brain learning.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-brain-chaotic-spiking-backpropagation.html'}], 'link': 'https://techxplore.com/news/2024-03-brain-chaotic-spiking-backpropagation.html', 'tags': [{'term': 'Computer Sciences', 'scheme': None, 'label': None}], 'published': 'Fri, 29 Mar 2024 13:58:02 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=29, tm_hour=17, tm_min=58, tm_sec=2, tm_wday=4, tm_yday=89, tm_isdst=0), 'id': 'news630939481', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/brain-inspired-chaotic.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Enhancing defect detection performance in smart factories', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Enhancing defect detection performance in smart factories'}, 'summary': "Prof. Sang Hyun Park's research team in the Department of Robotics and Mechatronics Engineering at DGIST has developed a logical anomaly detection technology in collaboration with a team from Stanford University. This technology is expected to significantly improve defect detection performance in smart factories by leveraging AI to identify logical anomalies in industrial images accurately.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "Prof. Sang Hyun Park's research team in the Department of Robotics and Mechatronics Engineering at DGIST has developed a logical anomaly detection technology in collaboration with a team from Stanford University. This technology is expected to significantly improve defect detection performance in smart factories by leveraging AI to identify logical anomalies in industrial images accurately."}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-defect-smart-factories.html'}], 'link': 'https://techxplore.com/news/2024-03-defect-smart-factories.html', 'tags': [{'term': 'Business', 'scheme': None, 'label': None}], 'published': 'Fri, 29 Mar 2024 13:36:32 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=29, tm_hour=17, tm_min=36, tm_sec=32, tm_wday=4, tm_yday=89, tm_isdst=0), 'id': 'news630938188', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/enhancing-defect-detec.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Next-generation AI semiconductor devices mimic the human brain', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Next-generation AI semiconductor devices mimic the human brain'}, 'summary': "A research team led by Prof. Kwon Hyuk-jun of the DGIST Department of Electrical Engineering and Computer Science has developed a next-generation AI semiconductor technology that mimics the human brain's efficiency in AI and neuromorphic systems.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "A research team led by Prof. Kwon Hyuk-jun of the DGIST Department of Electrical Engineering and Computer Science has developed a next-generation AI semiconductor technology that mimics the human brain's efficiency in AI and neuromorphic systems."}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-generation-ai-semiconductor-devices-mimic.html'}], 'link': 'https://techxplore.com/news/2024-03-generation-ai-semiconductor-devices-mimic.html', 'tags': [{'term': 'Electronics & Semiconductors', 'scheme': None, 'label': None}], 'published': 'Fri, 29 Mar 2024 13:36:26 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=29, tm_hour=17, tm_min=36, tm_sec=26, tm_wday=4, tm_yday=89, tm_isdst=0), 'id': 'news630938166', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/next-generation-artifi.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'How AI discriminates and what that means for your Google habit', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'How AI discriminates and what that means for your Google habit'}, 'summary': 'Safiya Umoja Noble swears she is not a Luddite. But she does think we could all learn a thing or two from the machine-bashing textile craftsmen in 19th-century Britain whose name is now synonymous with technological skepticism.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Safiya Umoja Noble swears she is not a Luddite. But she does think we could all learn a thing or two from the machine-bashing textile craftsmen in 19th-century Britain whose name is now synonymous with technological skepticism.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-ai-discriminates-google-habit.html'}], 'link': 'https://techxplore.com/news/2024-03-ai-discriminates-google-habit.html', 'tags': [{'term': 'Internet', 'scheme': None, 'label': None}], 'published': 'Fri, 29 Mar 2024 12:22:58 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=29, tm_hour=16, tm_min=22, tm_sec=58, tm_wday=4, tm_yday=89, tm_isdst=0), 'id': 'news630933768', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/how-ai-discriminates-a.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'DeepMind develops SAFE, an AI-based app that can fact-check LLMs', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'DeepMind develops SAFE, an AI-based app that can fact-check LLMs'}, 'summary': "A team of artificial intelligence specialists at Google's DeepMind has developed an AI-based system called SAFE that can be used to fact check the results of LLMs such as ChatGPT. The group has published a paper describing the new AI system and how well it performed on the arXiv preprint server.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "A team of artificial intelligence specialists at Google's DeepMind has developed an AI-based system called SAFE that can be used to fact check the results of LLMs such as ChatGPT. The group has published a paper describing the new AI system and how well it performed on the arXiv preprint server."}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-deepmind-safe-ai-based-app.html'}], 'link': 'https://techxplore.com/news/2024-03-deepmind-safe-ai-based-app.html', 'tags': [{'term': 'Computer Sciences', 'scheme': None, 'label': None}], 'published': 'Fri, 29 Mar 2024 09:32:00 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=29, tm_hour=13, tm_min=32, tm_sec=0, tm_wday=4, tm_yday=89, tm_isdst=0), 'id': 'news630923511', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2020/google.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Generative AI develops potential new drugs for antibiotic-resistant bacteria', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Generative AI develops potential new drugs for antibiotic-resistant bacteria'}, 'summary': 'With nearly 5 million deaths linked to antibiotic resistance globally every year, new ways to combat resistant bacterial strains are urgently needed.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'With nearly 5 million deaths linked to antibiotic resistance globally every year, new ways to combat resistant bacterial strains are urgently needed.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-generative-ai-potential-drugs-antibiotic.html'}], 'link': 'https://techxplore.com/news/2024-03-generative-ai-potential-drugs-antibiotic.html', 'tags': [{'term': 'Hi Tech & Innovation', 'scheme': None, 'label': None}], 'published': 'Thu, 28 Mar 2024 17:40:04 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=28, tm_hour=21, tm_min=40, tm_sec=4, tm_wday=3, tm_yday=88, tm_isdst=0), 'id': 'news630866386', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2020/acinetobacte.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': "Q&A: How to train AI when you don't have enough data", 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "Q&A: How to train AI when you don't have enough data"}, 'summary': 'Artificial intelligence excels at sorting through information and detecting patterns or trends. But these machine learning algorithms need to be trained with large amounts of data first.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Artificial intelligence excels at sorting through information and detecting patterns or trends. But these machine learning algorithms need to be trained with large amounts of data first.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-qa-ai-dont.html'}], 'link': 'https://techxplore.com/news/2024-03-qa-ai-dont.html', 'tags': [{'term': 'Computer Sciences', 'scheme': None, 'label': None}], 'published': 'Thu, 28 Mar 2024 16:49:00 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=28, tm_hour=20, tm_min=49, tm_sec=0, tm_wday=3, tm_yday=88, tm_isdst=0), 'id': 'news630863336', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/qa-how-to-train-ai-whe.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Stop out-of-control AI and focus on people, new book urges', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Stop out-of-control AI and focus on people, new book urges'}, 'summary': "In a new book co-edited by UdeM's Catherine Régis and Jean-Louis Denis, experts from a dozen countries and a dozen disciplines argue for a more human-centered approach to artificial intelligence.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "In a new book co-edited by UdeM's Catherine Régis and Jean-Louis Denis, experts from a dozen countries and a dozen disciplines argue for a more human-centered approach to artificial intelligence."}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-ai-focus-people-urges.html'}], 'link': 'https://techxplore.com/news/2024-03-ai-focus-people-urges.html', 'tags': [{'term': 'Other', 'scheme': None, 'label': None}], 'published': 'Thu, 28 Mar 2024 16:30:03 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=28, tm_hour=20, tm_min=30, tm_sec=3, tm_wday=3, tm_yday=88, tm_isdst=0), 'id': 'news630862201', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/ai-1.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Building energy efficiency: Enhancing HVAC fault detection with transformer and transfer learning', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Building energy efficiency: Enhancing HVAC fault detection with transformer and transfer learning'}, 'summary': 'Heating, ventilation, and air conditioning (HVAC) systems, a critical component of building energy consumption, are prone to faults that can reduce their efficiency. Traditional data-driven fault detection and diagnosis (FDD) models often suffer from limited generalizability, making their application across diverse systems challenging.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Heating, ventilation, and air conditioning (HVAC) systems, a critical component of building energy consumption, are prone to faults that can reduce their efficiency. Traditional data-driven fault detection and diagnosis (FDD) models often suffer from limited generalizability, making their application across diverse systems challenging.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-energy-efficiency-hvac-fault.html'}], 'link': 'https://techxplore.com/news/2024-03-energy-efficiency-hvac-fault.html', 'tags': [{'term': 'Energy & Green Tech', 'scheme': None, 'label': None}], 'published': 'Thu, 28 Mar 2024 15:08:02 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=28, tm_hour=19, tm_min=8, tm_sec=2, tm_wday=3, tm_yday=88, tm_isdst=0), 'id': 'news630857281', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/building-energy-effici.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Responsible AI: Three tools to help businesses', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Responsible AI: Three tools to help businesses'}, 'summary': 'Artificial Intelligence (AI) is one of the most powerful tools developed in recent decades. And, as the saying goes, with great power comes great responsibility.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Artificial Intelligence (AI) is one of the most powerful tools developed in recent decades. And, as the saying goes, with great power comes great responsibility.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-responsible-ai-tools-businesses.html'}], 'link': 'https://techxplore.com/news/2024-03-responsible-ai-tools-businesses.html', 'tags': [{'term': 'Business', 'scheme': None, 'label': None}], 'published': 'Thu, 28 Mar 2024 14:10:06 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=28, tm_hour=18, tm_min=10, tm_sec=6, tm_wday=3, tm_yday=88, tm_isdst=0), 'id': 'news630852558', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2023/ai-and-business.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'New report highlights global strategies for accelerating AI in science and research', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'New report highlights global strategies for accelerating AI in science and research'}, 'summary': 'A comprehensive analysis of the integration of artificial intelligence in science and research across various countries addresses both the advancements made and the challenges faced in this field.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'A comprehensive analysis of the integration of artificial intelligence in science and research across various countries addresses both the advancements made and the challenges faced in this field.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-highlights-global-strategies-ai-science.html'}], 'link': 'https://techxplore.com/news/2024-03-highlights-global-strategies-ai-science.html', 'tags': [{'term': 'Machine learning & AI', 'scheme': None, 'label': None}], 'published': 'Thu, 28 Mar 2024 14:06:02 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=28, tm_hour=18, tm_min=6, tm_sec=2, tm_wday=3, tm_yday=88, tm_isdst=0), 'id': 'news630853561', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/new-report-highlights.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': "Australian report maps sovereign capability to build 'foundational' AI tech", 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "Australian report maps sovereign capability to build 'foundational' AI tech"}, 'summary': "Foundation models, the technology underpinning the rise of generative artificial intelligence (AI), could boost Australia's productivity, bolster our economy, and transform industries according to a new report by CSIRO, Australia's national science agency.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "Foundation models, the technology underpinning the rise of generative artificial intelligence (AI), could boost Australia's productivity, bolster our economy, and transform industries according to a new report by CSIRO, Australia's national science agency."}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-australian-sovereign-capability-foundational-ai.html'}], 'link': 'https://techxplore.com/news/2024-03-australian-sovereign-capability-foundational-ai.html', 'tags': [{'term': 'Business', 'scheme': None, 'label': None}], 'published': 'Thu, 28 Mar 2024 14:05:03 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=28, tm_hour=18, tm_min=5, tm_sec=3, tm_wday=3, tm_yday=88, tm_isdst=0), 'id': 'news630853501', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/csiro-report-maps-sove.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Artificial intelligence boosts super-resolution microscopy', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Artificial intelligence boosts super-resolution microscopy'}, 'summary': 'Generative artificial intelligence (AI) might be best known from text or image-creating applications like ChatGPT or Stable Diffusion. But its usefulness beyond that is being shown in more and more different scientific fields.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Generative artificial intelligence (AI) might be best known from text or image-creating applications like ChatGPT or Stable Diffusion. But its usefulness beyond that is being shown in more and more different scientific fields.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-artificial-intelligence-boosts-super-resolution.html'}], 'link': 'https://techxplore.com/news/2024-03-artificial-intelligence-boosts-super-resolution.html', 'tags': [{'term': 'Computer Sciences', 'scheme': None, 'label': None}], 'published': 'Thu, 28 Mar 2024 13:33:05 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=28, tm_hour=17, tm_min=33, tm_sec=5, tm_wday=3, tm_yday=88, tm_isdst=0), 'id': 'news630851581', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/artificial-intelligenc-15.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'White House sets policies for federal AI use', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'White House sets policies for federal AI use'}, 'summary': '"Concrete safeguards" for government use of artificial intelligence were announced by the White House Thursday, as it vowed they would serve as a model for "global action."', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': '"Concrete safeguards" for government use of artificial intelligence were announced by the White House Thursday, as it vowed they would serve as a model for "global action."'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-white-house-policies-federal-ai.html'}], 'link': 'https://techxplore.com/news/2024-03-white-house-policies-federal-ai.html', 'tags': [{'term': 'Machine learning & AI', 'scheme': None, 'label': None}], 'published': 'Thu, 28 Mar 2024 08:47:53 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=28, tm_hour=12, tm_min=47, tm_sec=53, tm_wday=3, tm_yday=88, tm_isdst=0), 'id': 'news630834466', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2020/2-ai.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Amazon pours an additional $2.75 billion into AI startup Anthropic', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Amazon pours an additional $2.75 billion into AI startup Anthropic'}, 'summary': 'Amazon said Wednesday it is pouring an additional $2.75 billion into Anthropic, bringing its total investment in the artificial intelligence startup to $4 billion.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Amazon said Wednesday it is pouring an additional $2.75 billion into Anthropic, bringing its total investment in the artificial intelligence startup to $4 billion.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-amazon-additional-billion-ai-startup.html'}], 'link': 'https://techxplore.com/news/2024-03-amazon-additional-billion-ai-startup.html', 'tags': [{'term': 'Business', 'scheme': None, 'label': None}], 'published': 'Wed, 27 Mar 2024 16:50:54 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=27, tm_hour=20, tm_min=50, tm_sec=54, tm_wday=2, tm_yday=87, tm_isdst=0), 'id': 'news630777050', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/amazon-pours-an-additi.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': "Robotic face makes eye contact, uses AI to anticipate and replicate a person's smile before it occurs", 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "Robotic face makes eye contact, uses AI to anticipate and replicate a person's smile before it occurs"}, 'summary': "What would you do if you walked up to a robot with a human-like head and it smiled at you first? You'd likely smile back and perhaps feel the two of you were genuinely interacting. But how does a robot know how to do this? Or a better question, how does it know to get you to smile back?", 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "What would you do if you walked up to a robot with a human-like head and it smiled at you first? You'd likely smile back and perhaps feel the two of you were genuinely interacting. But how does a robot know how to do this? Or a better question, how does it know to get you to smile back?"}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-robotic-eye-contact-ai-replicate.html'}], 'link': 'https://techxplore.com/news/2024-03-robotic-eye-contact-ai-replicate.html', 'tags': [{'term': 'Robotics', 'scheme': None, 'label': None}], 'published': 'Wed, 27 Mar 2024 15:48:05 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=27, tm_hour=19, tm_min=48, tm_sec=5, tm_wday=2, tm_yday=87, tm_isdst=0), 'id': 'news630773281', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/robot-can-you-say-chee.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'At GDC 2024, tech companies offer a glimpse of AI-powered characters', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'At GDC 2024, tech companies offer a glimpse of AI-powered characters'}, 'summary': "Glimpses of the future often emerge at the Game Developers Conference. It's where indie games generate a buzz or the kernel of a big idea is planted. This year, artificial intelligence took center stage as Nvidia showed off jaw-dropping capabilities of its chipsets and software companies such as Convai and Ubisoft revealed intriguing gameplay opportunities.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "Glimpses of the future often emerge at the Game Developers Conference. It's where indie games generate a buzz or the kernel of a big idea is planted. This year, artificial intelligence took center stage as Nvidia showed off jaw-dropping capabilities of its chipsets and software companies such as Convai and Ubisoft revealed intriguing gameplay opportunities."}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-gdc-tech-companies-glimpse-ai.html'}], 'link': 'https://techxplore.com/news/2024-03-gdc-tech-companies-glimpse-ai.html', 'tags': [{'term': 'Business', 'scheme': None, 'label': None}], 'published': 'Wed, 27 Mar 2024 12:30:02 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=27, tm_hour=16, tm_min=30, tm_sec=2, tm_wday=2, tm_yday=87, tm_isdst=0), 'id': 'news630753993', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2020/nvidia.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Q&A: The flip side of safety is an attack on privacy—regulating face recognition technology', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Q&A: The flip side of safety is an attack on privacy—regulating face recognition technology'}, 'summary': 'If you bought a phone in the past few years, chances are you barely ever type your password anymore: your face unlocks not only your phone, but also your social media, your Duke MyChart portal and even your banking app.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'If you bought a phone in the past few years, chances are you barely ever type your password anymore: your face unlocks not only your phone, but also your social media, your Duke MyChart portal and even your banking app.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-qa-flip-side-safety-privacy.html'}], 'link': 'https://techxplore.com/news/2024-03-qa-flip-side-safety-privacy.html', 'tags': [{'term': 'Security', 'scheme': None, 'label': None}], 'published': 'Wed, 27 Mar 2024 11:22:14 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=27, tm_hour=15, tm_min=22, tm_sec=14, tm_wday=2, tm_yday=87, tm_isdst=0), 'id': 'news630757326', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/regulating-face-recogn-1.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'California looks to Europe to rein in AI', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'California looks to Europe to rein in AI'}, 'summary': "California, home to Silicon Valley, is eager to rein in the deployment of artificial intelligence and is looking to Europe's tough-on-big-tech approach for inspiration.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "California, home to Silicon Valley, is eager to rein in the deployment of artificial intelligence and is looking to Europe's tough-on-big-tech approach for inspiration."}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-california-europe-rein-ai.html'}], 'link': 'https://techxplore.com/news/2024-03-california-europe-rein-ai.html', 'tags': [{'term': 'Business', 'scheme': None, 'label': None}], 'published': 'Wed, 27 Mar 2024 04:51:01 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=27, tm_hour=8, tm_min=51, tm_sec=1, tm_wday=2, tm_yday=87, tm_isdst=0), 'id': 'news630733854', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/legislators-in-the-cal.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Food safety: Two-stage process of extraction and classification to identify ingredients in photos of food', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Food safety: Two-stage process of extraction and classification to identify ingredients in photos of food'}, 'summary': 'Research published in the International Journal of Reasoning-based Intelligent Systems discusses a new approach to the identification of ingredients in photographs of food. The work will be useful in our moving forward on food safety endeavors.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Research published in the International Journal of Reasoning-based Intelligent Systems discusses a new approach to the identification of ingredients in photographs of food. The work will be useful in our moving forward on food safety endeavors.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-food-safety-stage-classification-ingredients.html'}], 'link': 'https://techxplore.com/news/2024-03-food-safety-stage-classification-ingredients.html', 'tags': [{'term': 'Software', 'scheme': None, 'label': None}], 'published': 'Tue, 26 Mar 2024 10:05:51 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=26, tm_hour=14, tm_min=5, tm_sec=51, tm_wday=1, tm_yday=86, tm_isdst=0), 'id': 'news630666345', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2022/food.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': "Tired of AI doomsday tropes, Cohere CEO says his goal is technology that's 'additive to humanity'", 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "Tired of AI doomsday tropes, Cohere CEO says his goal is technology that's 'additive to humanity'"}, 'summary': "Aidan Gomez can take some credit for the 'T' at the end of ChatGPT. He was part of a group of Google engineers who first introduced a new artificial intelligence model called a transformer.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "Aidan Gomez can take some credit for the 'T' at the end of ChatGPT. He was part of a group of Google engineers who first introduced a new artificial intelligence model called a transformer."}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-ai-doomsday-tropes-cohere-ceo.html'}], 'link': 'https://techxplore.com/news/2024-03-ai-doomsday-tropes-cohere-ceo.html', 'tags': [{'term': 'Business', 'scheme': None, 'label': None}], 'published': 'Mon, 25 Mar 2024 17:05:57 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=25, tm_hour=21, tm_min=5, tm_sec=57, tm_wday=0, tm_yday=85, tm_isdst=0), 'id': 'news630605152', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/tired-of-ai-doomsday-t.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'A deep-learning and transfer-learning hybrid aerosol retrieval algorithm for a geostationary meteorological satellite', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'A deep-learning and transfer-learning hybrid aerosol retrieval algorithm for a geostationary meteorological satellite'}, 'summary': 'A study published in Engineering introduces an innovative high-precision aerosol algorithm for a geostationary meteorological satellite.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'A study published in Engineering introduces an innovative high-precision aerosol algorithm for a geostationary meteorological satellite.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-deep-hybrid-aerosol-algorithm-geostationary.html'}], 'link': 'https://techxplore.com/news/2024-03-deep-hybrid-aerosol-algorithm-geostationary.html', 'tags': [{'term': 'Engineering', 'scheme': None, 'label': None}], 'published': 'Mon, 25 Mar 2024 15:46:05 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=25, tm_hour=19, tm_min=46, tm_sec=5, tm_wday=0, tm_yday=85, tm_isdst=0), 'id': 'news630600361', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/a-deep-learning-and-tr.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'My search for the mysterious missing secretary who shaped chatbot history', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'My search for the mysterious missing secretary who shaped chatbot history'}, 'summary': "The Massachusetts Institute of Technology's (MIT) Distinctive Collections archive is quiet while the blizzard blows outside. Silence seems to be accumulating with the falling snow. I am the only researcher in the archive, but there is a voice that I am straining to hear.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "The Massachusetts Institute of Technology's (MIT) Distinctive Collections archive is quiet while the blizzard blows outside. Silence seems to be accumulating with the falling snow. I am the only researcher in the archive, but there is a voice that I am straining to hear."}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-mysterious-secretary-chatbot-history.html'}], 'link': 'https://techxplore.com/news/2024-03-mysterious-secretary-chatbot-history.html', 'tags': [{'term': 'Computer Sciences', 'scheme': None, 'label': None}], 'published': 'Mon, 25 Mar 2024 13:00:01 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=25, tm_hour=17, tm_min=0, tm_sec=1, tm_wday=0, tm_yday=85, tm_isdst=0), 'id': 'news630590079', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/a-secretary-inventing.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': "Research finds AI algorithms can help 'mumpreneurs'", 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "Research finds AI algorithms can help 'mumpreneurs'"}, 'summary': 'New research, led by academics from Royal Holloway, University of London found AI algorithms generated significant economic and non-economic value for "mumpreneurs."', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'New research, led by academics from Royal Holloway, University of London found AI algorithms generated significant economic and non-economic value for "mumpreneurs."'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-ai-algorithms-mumpreneurs.html'}], 'link': 'https://techxplore.com/news/2024-03-ai-algorithms-mumpreneurs.html', 'tags': [{'term': 'Business', 'scheme': None, 'label': None}], 'published': 'Mon, 25 Mar 2024 12:54:01 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=25, tm_hour=16, tm_min=54, tm_sec=1, tm_wday=0, tm_yday=85, tm_isdst=0), 'id': 'news630590036', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/instagram-business.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Study tests if AI can help fight cybercrime', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Study tests if AI can help fight cybercrime'}, 'summary': 'Artificial Intelligence (AI) could become a crucial asset to fight the growing global risk of cybercrime, a new study with Charles Darwin University (CDU) has found.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Artificial Intelligence (AI) could become a crucial asset to fight the growing global risk of cybercrime, a new study with Charles Darwin University (CDU) has found.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-ai-cybercrime.html'}], 'link': 'https://techxplore.com/news/2024-03-ai-cybercrime.html', 'tags': [{'term': 'Security', 'scheme': None, 'label': None}], 'published': 'Mon, 25 Mar 2024 09:48:48 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=25, tm_hour=13, tm_min=48, tm_sec=48, tm_wday=0, tm_yday=85, tm_isdst=0), 'id': 'news630578923', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2018/2-cybercrime.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Engineering household robots to have a little common sense', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Engineering household robots to have a little common sense'}, 'summary': 'From wiping up spills to serving up food, robots are being taught to carry out increasingly complicated household tasks. Many such home-bot trainees are learning through imitation; they are programmed to copy the motions that a human physically guides them through.', 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'From wiping up spills to serving up food, robots are being taught to carry out increasingly complicated household tasks. Many such home-bot trainees are learning through imitation; they are programmed to copy the motions that a human physically guides them through.'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-household-robots-common.html'}], 'link': 'https://techxplore.com/news/2024-03-household-robots-common.html', 'tags': [{'term': 'Robotics', 'scheme': None, 'label': None}], 'published': 'Mon, 25 Mar 2024 09:48:20 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=25, tm_hour=13, tm_min=48, tm_sec=20, tm_wday=0, tm_yday=85, tm_isdst=0), 'id': 'news630578897', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/engineering-household.jpg', 'width': '90', 'height': '90'}], 'href': ''}
# {'title': 'Large language models use a surprisingly simple mechanism to retrieve some stored knowledge', 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': 'Large language models use a surprisingly simple mechanism to retrieve some stored knowledge'}, 'summary': "Large language models, such as those that power popular artificial intelligence chatbots like ChatGPT, are incredibly complex. Even though these models are being used as tools in many areas, such as customer support, code generation, and language translation, scientists still don't fully grasp how they work.", 'summary_detail': {'type': 'text/html', 'language': None, 'base': 'https://techxplore.com/rss-feed/machine-learning-ai-news/', 'value': "Large language models, such as those that power popular artificial intelligence chatbots like ChatGPT, are incredibly complex. Even though these models are being used as tools in many areas, such as customer support, code generation, and language translation, scientists still don't fully grasp how they work."}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://techxplore.com/news/2024-03-large-language-simple-mechanism-knowledge.html'}], 'link': 'https://techxplore.com/news/2024-03-large-language-simple-mechanism-knowledge.html', 'tags': [{'term': 'Computer Sciences', 'scheme': None, 'label': None}], 'published': 'Mon, 25 Mar 2024 09:34:06 EDT', 'published_parsed': time.struct_time(tm_year=2024, tm_mon=3, tm_mday=25, tm_hour=13, tm_min=34, tm_sec=6, tm_wday=0, tm_yday=85, tm_isdst=0), 'id': 'news630578039', 'guidislink': False, 'media_thumbnail': [{'url': 'https://scx1.b-cdn.net/csz/news/tmb/2024/large-language-models-2.jpg', 'width': '90', 'height': '90'}], 'href': ''}
